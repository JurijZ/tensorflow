# %% [markdown]
# # Week 4: Predicting the next word
#
# Welcome to this assignment! During this week you saw how to create a model that will predict the next word in a text sequence, now you will implement such model and train it using a corpus of Shakespeare's sonnets, while also creating some helper functions to pre-process the data.
#
#
# Let's get started!

# %%
import numpy as np 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout, GRU
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# For this assignment you will be using the [Shakespeare Sonnets Dataset](https://www.opensourceshakespeare.org/views/sonnets/sonnet_view.php?range=viewrange&sonnetrange1=1&sonnetrange2=154), which contains more than 2000 lines of text extracted from Shakespeare's sonnets.

# %%
# sonnets.txt
# !gdown --id 108jAePKK4R3BVYBbYJZ32JWUwxeMg20K
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=108jAePKK4R3BVYBbYJZ32JWUwxeMg20K
# To: /content/sonnets.txt
# 100% 93.6k/93.6k [00:00<00:00, 93.4MB/s]

# %%
# Define path for file with sonnets
SONNETS_FILE = './sonnets.txt'

# Read the data
with open('./sonnets.txt') as f:
    data = f.read()

# Convert to lower case and save as a list
corpus = data.lower().split("\n")

print(f"There are {len(corpus)} lines of sonnets\n")
print(f"The first 5 lines look like this:\n")
for i in range(5):
  print(corpus[i])
# Out:
# There are 2159 lines of sonnets
#
# The first 5 lines look like this:
#
# from fairest creatures we desire increase,
# that thereby beauty's rose might never die,
# but as the riper should by time decease,
# his tender heir might bear his memory:
# but thou, contracted to thine own bright eyes,

# %% [markdown]
# ## Tokenizing the text
#
# Now fit the Tokenizer to the corpus and save the total number of words.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# %% [markdown]
# When converting the text into sequences you can use the `texts_to_sequences` method as you have done throughout this course.
#
# In the next graded function you will need to process this corpus one line at a time. Given this, it is important to keep in mind that the way you are feeding the data unto this method affects the result. Check the following example to make this clearer.
#
# The first example of the corpus is a string and looks like this:

# %%
corpus[0]
# Out:
# 'from fairest creatures we desire increase,'

# %% [markdown]
# If you pass this text directly into the `texts_to_sequences` method you will get an unexpected result:

# %%
tokenizer.texts_to_sequences(corpus[0])
# Out:
# [[],
#  [],
#  [58],
#  [],
#  [],
#  [],
#  [17],
#  [6],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [17],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [6],
#  [],
#  [],
#  [],
#  [6],
#  [],
#  [],
#  [],
#  [],
#  [17],
#  [],
#  [],
#  []]

# %% [markdown]
# This happened because `texts_to_sequences` expects a list and you are providing a string. However a string is still and `iterable` in Python so you will get the word index of every character in the string.
#
# Instead you need to place the example whithin a list before passing it to the method:

# %%
tokenizer.texts_to_sequences([corpus[0]])
# Out:
# [[34, 417, 877, 166, 213, 517]]

# %% [markdown]
# Notice that you received the sequence wrapped inside a list so in order to get only the desired sequence you need to explicitly get the first item in the list like this:

# %%
tokenizer.texts_to_sequences([corpus[0]])[0]
# Out:
# [34, 417, 877, 166, 213, 517]

# %% [markdown]
# ## Generating n_grams
#
# Now complete the `n_gram_seqs` function below. This function receives the fitted tokenizer and the corpus (which is a list of strings) and should return a list containing the `n_gram` sequences for each line in the corpus:

# %%
# GRADED FUNCTION: n_gram_seqs
def n_gram_seqs(corpus, tokenizer):
    """
    Generates a list of n-gram sequences
    
    Args:
        corpus (list of string): lines of texts to generate n-grams for
        tokenizer (object): an instance of the Tokenizer class containing the word-index dictionary
    
    Returns:
        input_sequences (list of int): the n-gram sequences for each line in the corpus
    """
    input_sequences = []
    
    ### START CODE HERE

    for sentence in corpus:
      words = sentence.split()
      print(words)
      for i in range(2,len(words) + 1):
        print(' '.join(words[:i]))
        input_sequences.append(tokenizer.texts_to_sequences([' '.join(words[:i])])[0])
    
    ### END CODE HERE
    
    return input_sequences

# %%
# Test your function with one example
first_example_sequence = n_gram_seqs([corpus[0]], tokenizer)

print("n_gram sequences for first example look like this:\n")
first_example_sequence
# Out:
# ['from', 'fairest', 'creatures', 'we', 'desire', 'increase,']
# from fairest
# from fairest creatures
# from fairest creatures we
# from fairest creatures we desire
# from fairest creatures we desire increase,
# n_gram sequences for first example look like this:
# [[34, 417],
#  [34, 417, 877],
#  [34, 417, 877, 166],
#  [34, 417, 877, 166, 213],
#  [34, 417, 877, 166, 213, 517]]

# %% [markdown]
# **Expected Output:**
#
# ```
# n_gram sequences for first example look like this:
#
# [[34, 417],
#  [34, 417, 877],
#  [34, 417, 877, 166],
#  [34, 417, 877, 166, 213],
#  [34, 417, 877, 166, 213, 517]]
# ```

# %%
# Test your function with a bigger corpus
next_3_examples_sequence = n_gram_seqs(corpus[1:4], tokenizer)

print("n_gram sequences for next 3 examples look like this:\n")
next_3_examples_sequence
# Out:
# ['that', 'thereby', "beauty's", 'rose', 'might', 'never', 'die,']
# that thereby
# that thereby beauty's
# that thereby beauty's rose
# that thereby beauty's rose might
# that thereby beauty's rose might never
# that thereby beauty's rose might never die,
# ['but', 'as', 'the', 'riper', 'should', 'by', 'time', 'decease,']
# but as
# but as the
# but as the riper
# but as the riper should
# but as the riper should by
# but as the riper should by time
# but as the riper should by time decease,
# ['his', 'tender', 'heir', 'might', 'bear', 'his', 'memory:']
# his tender
# his tender heir
# his tender heir might
# his tender heir might bear
# his tender heir might bear his
# his tender heir might bear his memory:
# n_gram sequences for next 3 examples look like this:
# [[8, 878],
#  [8, 878, 134],
#  [8, 878, 134, 351],
#  [8, 878, 134, 351, 102],
#  [8, 878, 134, 351, 102, 156],
#  [8, 878, 134, 351, 102, 156, 199],
#  [16, 22],
#  [16, 22, 2],
#  [16, 22, 2, 879],
#  [16, 22, 2, 879, 61],
#  [16, 22, 2, 879, 61, 30],
#  [16, 22, 2, 879, 61, 30, 48],
#  [16, 22, 2, 879, 61, 30, 48, 634],
#  [25, 311],
#  [25, 311, 635],
#  [25, 311, 635, 102],
#  [25, 311, 635, 102, 200],
#  [25, 311, 635, 102, 200, 25],
#  [25, 311, 635, 102, 200, 25, 278]]

# %% [markdown]
# **Expected Output:**
#
# ```
# n_gram sequences for next 3 examples look like this:
#
# [[8, 878],
#  [8, 878, 134],
#  [8, 878, 134, 351],
#  [8, 878, 134, 351, 102],
#  [8, 878, 134, 351, 102, 156],
#  [8, 878, 134, 351, 102, 156, 199],
#  [16, 22],
#  [16, 22, 2],
#  [16, 22, 2, 879],
#  [16, 22, 2, 879, 61],
#  [16, 22, 2, 879, 61, 30],
#  [16, 22, 2, 879, 61, 30, 48],
#  [16, 22, 2, 879, 61, 30, 48, 634],
#  [25, 311],
#  [25, 311, 635],
#  [25, 311, 635, 102],
#  [25, 311, 635, 102, 200],
#  [25, 311, 635, 102, 200, 25],
#  [25, 311, 635, 102, 200, 25, 278]]
# ```

# %% [markdown]
# Apply the `n_gram_seqs` transformation to the whole corpus and save the maximum sequence length to use it later:

# %%
# Apply the n_gram_seqs transformation to the whole corpus
input_sequences = n_gram_seqs(corpus, tokenizer)

# Save max length 
max_sequence_len = max([len(x) for x in input_sequences])

print(f"n_grams of input_sequences have length: {len(input_sequences)}")
print(f"maximum length of sequences is: {max_sequence_len}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ['thence', 'comes', 'it', 'that', 'my', 'name', 'receives', 'a', 'brand,']
# thence comes
# thence comes it
# thence comes it that
# thence comes it that my
# thence comes it that my name
# thence comes it that my name receives
# thence comes it that my name receives a
# thence comes it that my name receives a brand,
# ['and', 'almost', 'thence', 'my', 'nature', 'is', 'subdued']
# and almost
# and almost thence
# and almost thence my
# and almost thence my nature
# and almost thence my nature is
# and almost thence my nature is subdued
# ['to', 'what', 'it', 'works', 'in,', 'like', 'the', "dyer's", 'hand:']
# to what
# to what it
# to what it works
# to what it works in,
# to what it works in, like
# to what it works in, like the
# to what it works in, like the dyer's
# to what it works in, like the dyer's hand:
# ['pity', 'me', 'then', 'and', 'wish', 'i', 'were', "renew'd;"]
# pity me
# pity me then
# pity me then and
# pity me then and wish
# pity me then and wish i
# pity me then and wish i were
# pity me then and wish i were renew'd;
# ['whilst,', 'like', 'a', 'willing', 'patient,', 'i', 'will', 'drink']
# whilst, like
# whilst, like a
# whilst, like a willing
# whilst, like a willing patient,
# whilst, like a willing patient, i
# whilst, like a willing patient, i will
# whilst, like a willing patient, i will drink
# ['potions', 'of', 'eisel', "'gainst", 'my', 'strong', 'infection']
# potions of
# potions of eisel
# potions of eisel 'gainst
# potions of eisel 'gainst my
# potions of eisel 'gainst my strong
# potions of eisel 'gainst my strong infection
# ['no', 'bitterness', 'that', 'i', 'will', 'bitter', 'think,']
# no bitterness
# no bitterness that
# no bitterness that i
# no bitterness that i will
# no bitterness that i will bitter
# no bitterness that i will bitter think,
# ['nor', 'double', 'penance,', 'to', 'correct', 'correction.']
# nor double
# nor double penance,
# nor double penance, to
# nor double penance, to correct
# nor double penance, to correct correction.
# ['pity', 'me', 'then,', 'dear', 'friend,', 'and', 'i', 'assure', 'ye']
# pity me
# pity me then,
# pity me then, dear
# pity me then, dear friend,
# pity me then, dear friend, and
# pity me then, dear friend, and i
# pity me then, dear friend, and i assure
# pity me then, dear friend, and i assure ye
# ['even', 'that', 'your', 'pity', 'is', 'enough', 'to', 'cure', 'me.']
# even that
# even that your
# even that your pity
# even that your pity is
# even that your pity is enough
# even that your pity is enough to
# even that your pity is enough to cure
# even that your pity is enough to cure me.
# ['your', 'love', 'and', 'pity', 'doth', 'the', 'impression', 'fill']
# your love
# your love and
# your love and pity
# your love and pity doth
# your love and pity doth the
# your love and pity doth the impression
# your love and pity doth the impression fill
# ['which', 'vulgar', 'scandal', "stamp'd", 'upon', 'my', 'brow;']
# which vulgar
# which vulgar scandal
# which vulgar scandal stamp'd
# which vulgar scandal stamp'd upon
# which vulgar scandal stamp'd upon my
# which vulgar scandal stamp'd upon my brow;
# ['for', 'what', 'care', 'i', 'who', 'calls', 'me', 'well', 'or', 'ill,']
# for what
# for what care
# for what care i
# for what care i who
# for what care i who calls
# for what care i who calls me
# for what care i who calls me well
# for what care i who calls me well or
# for what care i who calls me well or ill,
# ['so', 'you', "o'er-green", 'my', 'bad,', 'my', 'good', 'allow?']
# so you
# so you o'er-green
# so you o'er-green my
# so you o'er-green my bad,
# so you o'er-green my bad, my
# so you o'er-green my bad, my good
# so you o'er-green my bad, my good allow?
# ['you', 'are', 'my', 'all', 'the', 'world,', 'and', 'i', 'must', 'strive']
# you are
# you are my
# you are my all
# you are my all the
# you are my all the world,
# you are my all the world, and
# you are my all the world, and i
# you are my all the world, and i must
# you are my all the world, and i must strive
# ['to', 'know', 'my', 'shames', 'and', 'praises', 'from', 'your', 'tongue:']
# to know
# to know my
# to know my shames
# to know my shames and
# to know my shames and praises
# to know my shames and praises from
# to know my shames and praises from your
# to know my shames and praises from your tongue:
# ['none', 'else', 'to', 'me,', 'nor', 'i', 'to', 'none', 'alive,']
# none else
# none else to
# none else to me,
# none else to me, nor
# none else to me, nor i
# none else to me, nor i to
# none else to me, nor i to none
# none else to me, nor i to none alive,
# ['that', 'my', "steel'd", 'sense', 'or', 'changes', 'right', 'or', 'wrong.']
# that my
# that my steel'd
# that my steel'd sense
# that my steel'd sense or
# that my steel'd sense or changes
# that my steel'd sense or changes right
# that my steel'd sense or changes right or
# that my steel'd sense or changes right or wrong.
# ['in', 'so', 'profound', 'abysm', 'i', 'throw', 'all', 'care']
# in so
# in so profound
# in so profound abysm
# in so profound abysm i
# in so profound abysm i throw
# in so profound abysm i throw all
# in so profound abysm i throw all care
# ['of', "others'", 'voices,', 'that', 'my', "adder's", 'sense']
# of others'
# of others' voices,
# of others' voices, that
# of others' voices, that my
# of others' voices, that my adder's
# of others' voices, that my adder's sense
# ['to', 'critic', 'and', 'to', 'flatterer', 'stopped', 'are.']
# to critic
# to critic and
# to critic and to
# to critic and to flatterer
# to critic and to flatterer stopped
# to critic and to flatterer stopped are.
# ['mark', 'how', 'with', 'my', 'neglect', 'i', 'do', 'dispense:']
# mark how
# mark how with
# mark how with my
# mark how with my neglect
# mark how with my neglect i
# mark how with my neglect i do
# mark how with my neglect i do dispense:
# ['you', 'are', 'so', 'strongly', 'in', 'my', 'purpose', 'bred']
# you are
# you are so
# you are so strongly
# you are so strongly in
# you are so strongly in my
# you are so strongly in my purpose
# you are so strongly in my purpose bred
# ['that', 'all', 'the', 'world', 'besides', 'methinks', 'are', 'dead.']
# that all
# that all the
# that all the world
# that all the world besides
# that all the world besides methinks
# that all the world besides methinks are
# that all the world besides methinks are dead.
# ['since', 'i', 'left', 'you,', 'mine', 'eye', 'is', 'in', 'my', 'mind;']
# since i
# since i left
# since i left you,
# since i left you, mine
# since i left you, mine eye
# since i left you, mine eye is
# since i left you, mine eye is in
# since i left you, mine eye is in my
# since i left you, mine eye is in my mind;
# ['and', 'that', 'which', 'governs', 'me', 'to', 'go', 'about']
# and that
# and that which
# and that which governs
# and that which governs me
# and that which governs me to
# and that which governs me to go
# and that which governs me to go about
# ['doth', 'part', 'his', 'function', 'and', 'is', 'partly', 'blind,']
# doth part
# doth part his
# doth part his function
# doth part his function and
# doth part his function and is
# doth part his function and is partly
# doth part his function and is partly blind,
# ['seems', 'seeing,', 'but', 'effectually', 'is', 'out;']
# seems seeing,
# seems seeing, but
# seems seeing, but effectually
# seems seeing, but effectually is
# seems seeing, but effectually is out;
# ['for', 'it', 'no', 'form', 'delivers', 'to', 'the', 'heart']
# for it
# for it no
# for it no form
# for it no form delivers
# for it no form delivers to
# for it no form delivers to the
# for it no form delivers to the heart
# ['of', 'bird', 'of', 'flower,', 'or', 'shape,', 'which', 'it', 'doth', 'latch:']
# of bird
# of bird of
# of bird of flower,
# of bird of flower, or
# of bird of flower, or shape,
# of bird of flower, or shape, which
# of bird of flower, or shape, which it
# of bird of flower, or shape, which it doth
# of bird of flower, or shape, which it doth latch:
# ['of', 'his', 'quick', 'objects', 'hath', 'the', 'mind', 'no', 'part,']
# of his
# of his quick
# of his quick objects
# of his quick objects hath
# of his quick objects hath the
# of his quick objects hath the mind
# of his quick objects hath the mind no
# of his quick objects hath the mind no part,
# ['nor', 'his', 'own', 'vision', 'holds', 'what', 'it', 'doth', 'catch:']
# nor his
# nor his own
# nor his own vision
# nor his own vision holds
# nor his own vision holds what
# nor his own vision holds what it
# nor his own vision holds what it doth
# nor his own vision holds what it doth catch:
# ['for', 'if', 'it', 'see', 'the', 'rudest', 'or', 'gentlest', 'sight,']
# for if
# for if it
# for if it see
# for if it see the
# for if it see the rudest
# for if it see the rudest or
# for if it see the rudest or gentlest
# for if it see the rudest or gentlest sight,
# ['the', 'most', 'sweet', 'favour', 'or', "deformed'st", 'creature,']
# the most
# the most sweet
# the most sweet favour
# the most sweet favour or
# the most sweet favour or deformed'st
# the most sweet favour or deformed'st creature,
# ['the', 'mountain', 'or', 'the', 'sea,', 'the', 'day', 'or', 'night,']
# the mountain
# the mountain or
# the mountain or the
# the mountain or the sea,
# the mountain or the sea, the
# the mountain or the sea, the day
# the mountain or the sea, the day or
# the mountain or the sea, the day or night,
# ['the', 'crow', 'or', 'dove,', 'it', 'shapes', 'them', 'to', 'your', 'feature:']
# the crow
# the crow or
# the crow or dove,
# the crow or dove, it
# the crow or dove, it shapes
# the crow or dove, it shapes them
# the crow or dove, it shapes them to
# the crow or dove, it shapes them to your
# the crow or dove, it shapes them to your feature:
# ['incapable', 'of', 'more,', 'replete', 'with', 'you,']
# incapable of
# incapable of more,
# incapable of more, replete
# incapable of more, replete with
# incapable of more, replete with you,
# ['my', 'most', 'true', 'mind', 'thus', 'makes', 'mine', 'eye', 'untrue.']
# my most
# my most true
# my most true mind
# my most true mind thus
# my most true mind thus makes
# my most true mind thus makes mine
# my most true mind thus makes mine eye
# my most true mind thus makes mine eye untrue.
# ['or', 'whether', 'doth', 'my', 'mind,', 'being', "crown'd", 'with', 'you,']
# or whether
# or whether doth
# or whether doth my
# or whether doth my mind,
# or whether doth my mind, being
# or whether doth my mind, being crown'd
# or whether doth my mind, being crown'd with
# or whether doth my mind, being crown'd with you,
# ['drink', 'up', 'the', "monarch's", 'plague,', 'this', 'flattery?']
# drink up
# drink up the
# drink up the monarch's
# drink up the monarch's plague,
# drink up the monarch's plague, this
# drink up the monarch's plague, this flattery?
# ['or', 'whether', 'shall', 'i', 'say,', 'mine', 'eye', 'saith', 'true,']
# or whether
# or whether shall
# or whether shall i
# or whether shall i say,
# or whether shall i say, mine
# or whether shall i say, mine eye
# or whether shall i say, mine eye saith
# or whether shall i say, mine eye saith true,
# ['and', 'that', 'your', 'love', 'taught', 'it', 'this', 'alchemy,']
# and that
# and that your
# and that your love
# and that your love taught
# and that your love taught it
# and that your love taught it this
# and that your love taught it this alchemy,
# ['to', 'make', 'of', 'monsters', 'and', 'things', 'indigest']
# to make
# to make of
# to make of monsters
# to make of monsters and
# to make of monsters and things
# to make of monsters and things indigest
# ['such', 'cherubins', 'as', 'your', 'sweet', 'self', 'resemble,']
# such cherubins
# such cherubins as
# such cherubins as your
# such cherubins as your sweet
# such cherubins as your sweet self
# such cherubins as your sweet self resemble,
# ['creating', 'every', 'bad', 'a', 'perfect', 'best,']
# creating every
# creating every bad
# creating every bad a
# creating every bad a perfect
# creating every bad a perfect best,
# ['as', 'fast', 'as', 'objects', 'to', 'his', 'beams', 'assemble?']
# as fast
# as fast as
# as fast as objects
# as fast as objects to
# as fast as objects to his
# as fast as objects to his beams
# as fast as objects to his beams assemble?
# ["o,'tis", 'the', 'first;', "'tis", 'flattery', 'in', 'my', 'seeing,']
# o,'tis the
# o,'tis the first;
# o,'tis the first; 'tis
# o,'tis the first; 'tis flattery
# o,'tis the first; 'tis flattery in
# o,'tis the first; 'tis flattery in my
# o,'tis the first; 'tis flattery in my seeing,
# ['and', 'my', 'great', 'mind', 'most', 'kingly', 'drinks', 'it', 'up:']
# and my
# and my great
# and my great mind
# and my great mind most
# and my great mind most kingly
# and my great mind most kingly drinks
# and my great mind most kingly drinks it
# and my great mind most kingly drinks it up:
# ['mine', 'eye', 'well', 'knows', 'what', 'with', 'his', 'gust', 'is', "'greeing,"]
# mine eye
# mine eye well
# mine eye well knows
# mine eye well knows what
# mine eye well knows what with
# mine eye well knows what with his
# mine eye well knows what with his gust
# mine eye well knows what with his gust is
# mine eye well knows what with his gust is 'greeing,
# ['and', 'to', 'his', 'palate', 'doth', 'prepare', 'the', 'cup:']
# and to
# and to his
# and to his palate
# and to his palate doth
# and to his palate doth prepare
# and to his palate doth prepare the
# and to his palate doth prepare the cup:
# ['if', 'it', 'be', "poison'd,", "'tis", 'the', 'lesser', 'sin']
# if it
# if it be
# if it be poison'd,
# if it be poison'd, 'tis
# if it be poison'd, 'tis the
# if it be poison'd, 'tis the lesser
# if it be poison'd, 'tis the lesser sin
# ['that', 'mine', 'eye', 'loves', 'it', 'and', 'doth', 'first', 'begin.']
# that mine
# that mine eye
# that mine eye loves
# that mine eye loves it
# that mine eye loves it and
# that mine eye loves it and doth
# that mine eye loves it and doth first
# that mine eye loves it and doth first begin.
# ['those', 'lines', 'that', 'i', 'before', 'have', 'writ', 'do', 'lie,']
# those lines
# those lines that
# those lines that i
# those lines that i before
# those lines that i before have
# those lines that i before have writ
# those lines that i before have writ do
# those lines that i before have writ do lie,
# ['even', 'those', 'that', 'said', 'i', 'could', 'not', 'love', 'you', 'dearer:']
# even those
# even those that
# even those that said
# even those that said i
# even those that said i could
# even those that said i could not
# even those that said i could not love
# even those that said i could not love you
# even those that said i could not love you dearer:
# ['yet', 'then', 'my', 'judgment', 'knew', 'no', 'reason', 'why']
# yet then
# yet then my
# yet then my judgment
# yet then my judgment knew
# yet then my judgment knew no
# yet then my judgment knew no reason
# yet then my judgment knew no reason why
# ['my', 'most', 'full', 'flame', 'should', 'afterwards', 'burn', 'clearer.']
# my most
# my most full
# my most full flame
# my most full flame should
# my most full flame should afterwards
# my most full flame should afterwards burn
# my most full flame should afterwards burn clearer.
# ['but', 'reckoning', 'time,', 'whose', "million'd", 'accidents']
# but reckoning
# but reckoning time,
# but reckoning time, whose
# but reckoning time, whose million'd
# but reckoning time, whose million'd accidents
# ['creep', 'in', "'twixt", 'vows', 'and', 'change', 'decrees', 'of', 'kings,']
# creep in
# creep in 'twixt
# creep in 'twixt vows
# creep in 'twixt vows and
# creep in 'twixt vows and change
# creep in 'twixt vows and change decrees
# creep in 'twixt vows and change decrees of
# creep in 'twixt vows and change decrees of kings,
# ['tan', 'sacred', 'beauty,', 'blunt', 'the', "sharp'st", 'intents,']
# tan sacred
# tan sacred beauty,
# tan sacred beauty, blunt
# tan sacred beauty, blunt the
# tan sacred beauty, blunt the sharp'st
# tan sacred beauty, blunt the sharp'st intents,
# ['divert', 'strong', 'minds', 'to', 'the', 'course', 'of', 'altering', 'things;']
# divert strong
# divert strong minds
# divert strong minds to
# divert strong minds to the
# divert strong minds to the course
# divert strong minds to the course of
# divert strong minds to the course of altering
# divert strong minds to the course of altering things;
# ['alas,', 'why,', 'fearing', 'of', "time's", 'tyranny,']
# alas, why,
# alas, why, fearing
# alas, why, fearing of
# alas, why, fearing of time's
# alas, why, fearing of time's tyranny,
# ['might', 'i', 'not', 'then', 'say', "'now", 'i', 'love', 'you', "best,'"]
# might i
# might i not
# might i not then
# might i not then say
# might i not then say 'now
# might i not then say 'now i
# might i not then say 'now i love
# might i not then say 'now i love you
# might i not then say 'now i love you best,'
# ['when', 'i', 'was', 'certain', "o'er", 'incertainty,']
# when i
# when i was
# when i was certain
# when i was certain o'er
# when i was certain o'er incertainty,
# ['crowning', 'the', 'present,', 'doubting', 'of', 'the', 'rest?']
# crowning the
# crowning the present,
# crowning the present, doubting
# crowning the present, doubting of
# crowning the present, doubting of the
# crowning the present, doubting of the rest?
# ['love', 'is', 'a', 'babe;', 'then', 'might', 'i', 'not', 'say', 'so,']
# love is
# love is a
# love is a babe;
# love is a babe; then
# love is a babe; then might
# love is a babe; then might i
# love is a babe; then might i not
# love is a babe; then might i not say
# love is a babe; then might i not say so,
# ['to', 'give', 'full', 'growth', 'to', 'that', 'which', 'still', 'doth', 'grow?']
# to give
# to give full
# to give full growth
# to give full growth to
# to give full growth to that
# to give full growth to that which
# to give full growth to that which still
# to give full growth to that which still doth
# to give full growth to that which still doth grow?
# ['let', 'me', 'not', 'to', 'the', 'marriage', 'of', 'true', 'minds']
# let me
# let me not
# let me not to
# let me not to the
# let me not to the marriage
# let me not to the marriage of
# let me not to the marriage of true
# let me not to the marriage of true minds
# ['admit', 'impediments.', 'love', 'is', 'not', 'love']
# admit impediments.
# admit impediments. love
# admit impediments. love is
# admit impediments. love is not
# admit impediments. love is not love
# ['which', 'alters', 'when', 'it', 'alteration', 'finds,']
# which alters
# which alters when
# which alters when it
# which alters when it alteration
# which alters when it alteration finds,
# ['or', 'bends', 'with', 'the', 'remover', 'to', 'remove:']
# or bends
# or bends with
# or bends with the
# or bends with the remover
# or bends with the remover to
# or bends with the remover to remove:
# ['o', 'no!', 'it', 'is', 'an', 'ever-fixed', 'mark']
# o no!
# o no! it
# o no! it is
# o no! it is an
# o no! it is an ever-fixed
# o no! it is an ever-fixed mark
# ['that', 'looks', 'on', 'tempests', 'and', 'is', 'never', 'shaken;']
# that looks
# that looks on
# that looks on tempests
# that looks on tempests and
# that looks on tempests and is
# that looks on tempests and is never
# that looks on tempests and is never shaken;
# ['it', 'is', 'the', 'star', 'to', 'every', 'wandering', 'bark,']
# it is
# it is the
# it is the star
# it is the star to
# it is the star to every
# it is the star to every wandering
# it is the star to every wandering bark,
# ['whose', "worth's", 'unknown,', 'although', 'his', 'height', 'be', 'taken.']
# whose worth's
# whose worth's unknown,
# whose worth's unknown, although
# whose worth's unknown, although his
# whose worth's unknown, although his height
# whose worth's unknown, although his height be
# whose worth's unknown, although his height be taken.
# ["love's", 'not', "time's", 'fool,', 'though', 'rosy', 'lips', 'and', 'cheeks']
# love's not
# love's not time's
# love's not time's fool,
# love's not time's fool, though
# love's not time's fool, though rosy
# love's not time's fool, though rosy lips
# love's not time's fool, though rosy lips and
# love's not time's fool, though rosy lips and cheeks
# ['within', 'his', 'bending', "sickle's", 'compass', 'come:']
# within his
# within his bending
# within his bending sickle's
# within his bending sickle's compass
# within his bending sickle's compass come:
# ['love', 'alters', 'not', 'with', 'his', 'brief', 'hours', 'and', 'weeks,']
# love alters
# love alters not
# love alters not with
# love alters not with his
# love alters not with his brief
# love alters not with his brief hours
# love alters not with his brief hours and
# love alters not with his brief hours and weeks,
# ['but', 'bears', 'it', 'out', 'even', 'to', 'the', 'edge', 'of', 'doom.']
# but bears
# but bears it
# but bears it out
# but bears it out even
# but bears it out even to
# but bears it out even to the
# but bears it out even to the edge
# but bears it out even to the edge of
# but bears it out even to the edge of doom.
# ['if', 'this', 'be', 'error', 'and', 'upon', 'me', 'proved,']
# if this
# if this be
# if this be error
# if this be error and
# if this be error and upon
# if this be error and upon me
# if this be error and upon me proved,
# ['i', 'never', 'writ,', 'nor', 'no', 'man', 'ever', 'loved.']
# i never
# i never writ,
# i never writ, nor
# i never writ, nor no
# i never writ, nor no man
# i never writ, nor no man ever
# i never writ, nor no man ever loved.
# ['accuse', 'me', 'thus:', 'that', 'i', 'have', 'scanted', 'all']
# accuse me
# accuse me thus:
# accuse me thus: that
# accuse me thus: that i
# accuse me thus: that i have
# accuse me thus: that i have scanted
# accuse me thus: that i have scanted all
# ['wherein', 'i', 'should', 'your', 'great', 'deserts', 'repay,']
# wherein i
# wherein i should
# wherein i should your
# wherein i should your great
# wherein i should your great deserts
# wherein i should your great deserts repay,
# ['forgot', 'upon', 'your', 'dearest', 'love', 'to', 'call,']
# forgot upon
# forgot upon your
# forgot upon your dearest
# forgot upon your dearest love
# forgot upon your dearest love to
# forgot upon your dearest love to call,
# ['whereto', 'all', 'bonds', 'do', 'tie', 'me', 'day', 'by', 'day;']
# whereto all
# whereto all bonds
# whereto all bonds do
# whereto all bonds do tie
# whereto all bonds do tie me
# whereto all bonds do tie me day
# whereto all bonds do tie me day by
# whereto all bonds do tie me day by day;
# ['that', 'i', 'have', 'frequent', 'been', 'with', 'unknown', 'minds']
# that i
# that i have
# that i have frequent
# that i have frequent been
# that i have frequent been with
# that i have frequent been with unknown
# that i have frequent been with unknown minds
# ['and', 'given', 'to', 'time', 'your', 'own', 'dear-purchased', 'right']
# and given
# and given to
# and given to time
# and given to time your
# and given to time your own
# and given to time your own dear-purchased
# and given to time your own dear-purchased right
# ['that', 'i', 'have', 'hoisted', 'sail', 'to', 'all', 'the', 'winds']
# that i
# that i have
# that i have hoisted
# that i have hoisted sail
# that i have hoisted sail to
# that i have hoisted sail to all
# that i have hoisted sail to all the
# that i have hoisted sail to all the winds
# ['which', 'should', 'transport', 'me', 'farthest', 'from', 'your', 'sight.']
# which should
# which should transport
# which should transport me
# which should transport me farthest
# which should transport me farthest from
# which should transport me farthest from your
# which should transport me farthest from your sight.
# ['book', 'both', 'my', 'wilfulness', 'and', 'errors', 'down']
# book both
# book both my
# book both my wilfulness
# book both my wilfulness and
# book both my wilfulness and errors
# book both my wilfulness and errors down
# ['and', 'on', 'just', 'proof', 'surmise', 'accumulate;']
# and on
# and on just
# and on just proof
# and on just proof surmise
# and on just proof surmise accumulate;
# ['bring', 'me', 'within', 'the', 'level', 'of', 'your', 'frown,']
# bring me
# bring me within
# bring me within the
# bring me within the level
# bring me within the level of
# bring me within the level of your
# bring me within the level of your frown,
# ['but', 'shoot', 'not', 'at', 'me', 'in', 'your', "waken'd", 'hate;']
# but shoot
# but shoot not
# but shoot not at
# but shoot not at me
# but shoot not at me in
# but shoot not at me in your
# but shoot not at me in your waken'd
# but shoot not at me in your waken'd hate;
# ['since', 'my', 'appeal', 'says', 'i', 'did', 'strive', 'to', 'prove']
# since my
# since my appeal
# since my appeal says
# since my appeal says i
# since my appeal says i did
# since my appeal says i did strive
# since my appeal says i did strive to
# since my appeal says i did strive to prove
# ['the', 'constancy', 'and', 'virtue', 'of', 'your', 'love.']
# the constancy
# the constancy and
# the constancy and virtue
# the constancy and virtue of
# the constancy and virtue of your
# the constancy and virtue of your love.
# ['like', 'as,', 'to', 'make', 'our', 'appetites', 'more', 'keen,']
# like as,
# like as, to
# like as, to make
# like as, to make our
# like as, to make our appetites
# like as, to make our appetites more
# like as, to make our appetites more keen,
# ['with', 'eager', 'compounds', 'we', 'our', 'palate', 'urge,']
# with eager
# with eager compounds
# with eager compounds we
# with eager compounds we our
# with eager compounds we our palate
# with eager compounds we our palate urge,
# ['as,', 'to', 'prevent', 'our', 'maladies', 'unseen,']
# as, to
# as, to prevent
# as, to prevent our
# as, to prevent our maladies
# as, to prevent our maladies unseen,
# ['we', 'sicken', 'to', 'shun', 'sickness', 'when', 'we', 'purge,']
# we sicken
# we sicken to
# we sicken to shun
# we sicken to shun sickness
# we sicken to shun sickness when
# we sicken to shun sickness when we
# we sicken to shun sickness when we purge,
# ['even', 'so,', 'being', 'full', 'of', 'your', "ne'er-cloying", 'sweetness,']
# even so,
# even so, being
# even so, being full
# even so, being full of
# even so, being full of your
# even so, being full of your ne'er-cloying
# even so, being full of your ne'er-cloying sweetness,
# ['to', 'bitter', 'sauces', 'did', 'i', 'frame', 'my', 'feeding']
# to bitter
# to bitter sauces
# to bitter sauces did
# to bitter sauces did i
# to bitter sauces did i frame
# to bitter sauces did i frame my
# to bitter sauces did i frame my feeding
# ['and,', 'sick', 'of', 'welfare,', 'found', 'a', 'kind', 'of', 'meetness']
# and, sick
# and, sick of
# and, sick of welfare,
# and, sick of welfare, found
# and, sick of welfare, found a
# and, sick of welfare, found a kind
# and, sick of welfare, found a kind of
# and, sick of welfare, found a kind of meetness
# ['to', 'be', 'diseased', 'ere', 'that', 'there', 'was', 'true', 'needing.']
# to be
# to be diseased
# to be diseased ere
# to be diseased ere that
# to be diseased ere that there
# to be diseased ere that there was
# to be diseased ere that there was true
# to be diseased ere that there was true needing.
# ['thus', 'policy', 'in', 'love,', 'to', 'anticipate']
# thus policy
# thus policy in
# thus policy in love,
# thus policy in love, to
# thus policy in love, to anticipate
# ['the', 'ills', 'that', 'were', 'not,', 'grew', 'to', 'faults', 'assured']
# the ills
# the ills that
# the ills that were
# the ills that were not,
# the ills that were not, grew
# the ills that were not, grew to
# the ills that were not, grew to faults
# the ills that were not, grew to faults assured
# ['and', 'brought', 'to', 'medicine', 'a', 'healthful', 'state']
# and brought
# and brought to
# and brought to medicine
# and brought to medicine a
# and brought to medicine a healthful
# and brought to medicine a healthful state
# ['which,', 'rank', 'of', 'goodness,', 'would', 'by', 'ill', 'be', 'cured:']
# which, rank
# which, rank of
# which, rank of goodness,
# which, rank of goodness, would
# which, rank of goodness, would by
# which, rank of goodness, would by ill
# which, rank of goodness, would by ill be
# which, rank of goodness, would by ill be cured:
# ['but', 'thence', 'i', 'learn,', 'and', 'find', 'the', 'lesson', 'true,']
# but thence
# but thence i
# but thence i learn,
# but thence i learn, and
# but thence i learn, and find
# but thence i learn, and find the
# but thence i learn, and find the lesson
# but thence i learn, and find the lesson true,
# ['drugs', 'poison', 'him', 'that', 'so', 'fell', 'sick', 'of', 'you.']
# drugs poison
# drugs poison him
# drugs poison him that
# drugs poison him that so
# drugs poison him that so fell
# drugs poison him that so fell sick
# drugs poison him that so fell sick of
# drugs poison him that so fell sick of you.
# ['what', 'potions', 'have', 'i', 'drunk', 'of', 'siren', 'tears,']
# what potions
# what potions have
# what potions have i
# what potions have i drunk
# what potions have i drunk of
# what potions have i drunk of siren
# what potions have i drunk of siren tears,
# ["distill'd", 'from', 'limbecks', 'foul', 'as', 'hell', 'within,']
# distill'd from
# distill'd from limbecks
# distill'd from limbecks foul
# distill'd from limbecks foul as
# distill'd from limbecks foul as hell
# distill'd from limbecks foul as hell within,
# ['applying', 'fears', 'to', 'hopes', 'and', 'hopes', 'to', 'fears,']
# applying fears
# applying fears to
# applying fears to hopes
# applying fears to hopes and
# applying fears to hopes and hopes
# applying fears to hopes and hopes to
# applying fears to hopes and hopes to fears,
# ['still', 'losing', 'when', 'i', 'saw', 'myself', 'to', 'win!']
# still losing
# still losing when
# still losing when i
# still losing when i saw
# still losing when i saw myself
# still losing when i saw myself to
# still losing when i saw myself to win!
# ['what', 'wretched', 'errors', 'hath', 'my', 'heart', 'committed,']
# what wretched
# what wretched errors
# what wretched errors hath
# what wretched errors hath my
# what wretched errors hath my heart
# what wretched errors hath my heart committed,
# ['whilst', 'it', 'hath', 'thought', 'itself', 'so', 'blessed', 'never!']
# whilst it
# whilst it hath
# whilst it hath thought
# whilst it hath thought itself
# whilst it hath thought itself so
# whilst it hath thought itself so blessed
# whilst it hath thought itself so blessed never!
# ['how', 'have', 'mine', 'eyes', 'out', 'of', 'their', 'spheres', 'been', 'fitted']
# how have
# how have mine
# how have mine eyes
# how have mine eyes out
# how have mine eyes out of
# how have mine eyes out of their
# how have mine eyes out of their spheres
# how have mine eyes out of their spheres been
# how have mine eyes out of their spheres been fitted
# ['in', 'the', 'distraction', 'of', 'this', 'madding', 'fever!']
# in the
# in the distraction
# in the distraction of
# in the distraction of this
# in the distraction of this madding
# in the distraction of this madding fever!
# ['o', 'benefit', 'of', 'ill!', 'now', 'i', 'find', 'true']
# o benefit
# o benefit of
# o benefit of ill!
# o benefit of ill! now
# o benefit of ill! now i
# o benefit of ill! now i find
# o benefit of ill! now i find true
# ['that', 'better', 'is', 'by', 'evil', 'still', 'made', 'better;']
# that better
# that better is
# that better is by
# that better is by evil
# that better is by evil still
# that better is by evil still made
# that better is by evil still made better;
# ['and', "ruin'd", 'love,', 'when', 'it', 'is', 'built', 'anew,']
# and ruin'd
# and ruin'd love,
# and ruin'd love, when
# and ruin'd love, when it
# and ruin'd love, when it is
# and ruin'd love, when it is built
# and ruin'd love, when it is built anew,
# ['grows', 'fairer', 'than', 'at', 'first,', 'more', 'strong,', 'far', 'greater.']
# grows fairer
# grows fairer than
# grows fairer than at
# grows fairer than at first,
# grows fairer than at first, more
# grows fairer than at first, more strong,
# grows fairer than at first, more strong, far
# grows fairer than at first, more strong, far greater.
# ['so', 'i', 'return', 'rebuked', 'to', 'my', 'content']
# so i
# so i return
# so i return rebuked
# so i return rebuked to
# so i return rebuked to my
# so i return rebuked to my content
# ['and', 'gain', 'by', 'ill', 'thrice', 'more', 'than', 'i', 'have', 'spent.']
# and gain
# and gain by
# and gain by ill
# and gain by ill thrice
# and gain by ill thrice more
# and gain by ill thrice more than
# and gain by ill thrice more than i
# and gain by ill thrice more than i have
# and gain by ill thrice more than i have spent.
# ['that', 'you', 'were', 'once', 'unkind', 'befriends', 'me', 'now,']
# that you
# that you were
# that you were once
# that you were once unkind
# that you were once unkind befriends
# that you were once unkind befriends me
# that you were once unkind befriends me now,
# ['and', 'for', 'that', 'sorrow', 'which', 'i', 'then', 'did', 'feel']
# and for
# and for that
# and for that sorrow
# and for that sorrow which
# and for that sorrow which i
# and for that sorrow which i then
# and for that sorrow which i then did
# and for that sorrow which i then did feel
# ['needs', 'must', 'i', 'under', 'my', 'transgression', 'bow,']
# needs must
# needs must i
# needs must i under
# needs must i under my
# needs must i under my transgression
# needs must i under my transgression bow,
# ['unless', 'my', 'nerves', 'were', 'brass', 'or', "hammer'd", 'steel.']
# unless my
# unless my nerves
# unless my nerves were
# unless my nerves were brass
# unless my nerves were brass or
# unless my nerves were brass or hammer'd
# unless my nerves were brass or hammer'd steel.
# ['for', 'if', 'you', 'were', 'by', 'my', 'unkindness', 'shaken']
# for if
# for if you
# for if you were
# for if you were by
# for if you were by my
# for if you were by my unkindness
# for if you were by my unkindness shaken
# ['as', 'i', 'by', 'yours,', "you've", "pass'd", 'a', 'hell', 'of', 'time,']
# as i
# as i by
# as i by yours,
# as i by yours, you've
# as i by yours, you've pass'd
# as i by yours, you've pass'd a
# as i by yours, you've pass'd a hell
# as i by yours, you've pass'd a hell of
# as i by yours, you've pass'd a hell of time,
# ['and', 'i,', 'a', 'tyrant,', 'have', 'no', 'leisure', 'taken']
# and i,
# and i, a
# and i, a tyrant,
# and i, a tyrant, have
# and i, a tyrant, have no
# and i, a tyrant, have no leisure
# and i, a tyrant, have no leisure taken
# ['to', 'weigh', 'how', 'once', 'i', 'suffered', 'in', 'your', 'crime.']
# to weigh
# to weigh how
# to weigh how once
# to weigh how once i
# to weigh how once i suffered
# to weigh how once i suffered in
# to weigh how once i suffered in your
# to weigh how once i suffered in your crime.
# ['o,', 'that', 'our', 'night', 'of', 'woe', 'might', 'have', "remember'd"]
# o, that
# o, that our
# o, that our night
# o, that our night of
# o, that our night of woe
# o, that our night of woe might
# o, that our night of woe might have
# o, that our night of woe might have remember'd
# ['my', 'deepest', 'sense,', 'how', 'hard', 'true', 'sorrow', 'hits,']
# my deepest
# my deepest sense,
# my deepest sense, how
# my deepest sense, how hard
# my deepest sense, how hard true
# my deepest sense, how hard true sorrow
# my deepest sense, how hard true sorrow hits,
# ['and', 'soon', 'to', 'you,', 'as', 'you', 'to', 'me,', 'then', "tender'd"]
# and soon
# and soon to
# and soon to you,
# and soon to you, as
# and soon to you, as you
# and soon to you, as you to
# and soon to you, as you to me,
# and soon to you, as you to me, then
# and soon to you, as you to me, then tender'd
# ['the', 'humble', 'salve', 'which', 'wounded', 'bosoms', 'fits!']
# the humble
# the humble salve
# the humble salve which
# the humble salve which wounded
# the humble salve which wounded bosoms
# the humble salve which wounded bosoms fits!
# ['but', 'that', 'your', 'trespass', 'now', 'becomes', 'a', 'fee;']
# but that
# but that your
# but that your trespass
# but that your trespass now
# but that your trespass now becomes
# but that your trespass now becomes a
# but that your trespass now becomes a fee;
# ['mine', 'ransoms', 'yours,', 'and', 'yours', 'must', 'ransom', 'me.']
# mine ransoms
# mine ransoms yours,
# mine ransoms yours, and
# mine ransoms yours, and yours
# mine ransoms yours, and yours must
# mine ransoms yours, and yours must ransom
# mine ransoms yours, and yours must ransom me.
# ["'tis", 'better', 'to', 'be', 'vile', 'than', 'vile', "esteem'd,"]
# 'tis better
# 'tis better to
# 'tis better to be
# 'tis better to be vile
# 'tis better to be vile than
# 'tis better to be vile than vile
# 'tis better to be vile than vile esteem'd,
# ['when', 'not', 'to', 'be', 'receives', 'reproach', 'of', 'being,']
# when not
# when not to
# when not to be
# when not to be receives
# when not to be receives reproach
# when not to be receives reproach of
# when not to be receives reproach of being,
# ['and', 'the', 'just', 'pleasure', 'lost', 'which', 'is', 'so', "deem'd"]
# and the
# and the just
# and the just pleasure
# and the just pleasure lost
# and the just pleasure lost which
# and the just pleasure lost which is
# and the just pleasure lost which is so
# and the just pleasure lost which is so deem'd
# ['not', 'by', 'our', 'feeling', 'but', 'by', "others'", 'seeing:']
# not by
# not by our
# not by our feeling
# not by our feeling but
# not by our feeling but by
# not by our feeling but by others'
# not by our feeling but by others' seeing:
# ['for', 'why', 'should', 'others', 'false', 'adulterate', 'eyes']
# for why
# for why should
# for why should others
# for why should others false
# for why should others false adulterate
# for why should others false adulterate eyes
# ['give', 'salutation', 'to', 'my', 'sportive', 'blood?']
# give salutation
# give salutation to
# give salutation to my
# give salutation to my sportive
# give salutation to my sportive blood?
# ['or', 'on', 'my', 'frailties', 'why', 'are', 'frailer', 'spies,']
# or on
# or on my
# or on my frailties
# or on my frailties why
# or on my frailties why are
# or on my frailties why are frailer
# or on my frailties why are frailer spies,
# ['which', 'in', 'their', 'wills', 'count', 'bad', 'what', 'i', 'think', 'good?']
# which in
# which in their
# which in their wills
# which in their wills count
# which in their wills count bad
# which in their wills count bad what
# which in their wills count bad what i
# which in their wills count bad what i think
# which in their wills count bad what i think good?
# ['no,', 'i', 'am', 'that', 'i', 'am,', 'and', 'they', 'that', 'level']
# no, i
# no, i am
# no, i am that
# no, i am that i
# no, i am that i am,
# no, i am that i am, and
# no, i am that i am, and they
# no, i am that i am, and they that
# no, i am that i am, and they that level
# ['at', 'my', 'abuses', 'reckon', 'up', 'their', 'own:']
# at my
# at my abuses
# at my abuses reckon
# at my abuses reckon up
# at my abuses reckon up their
# at my abuses reckon up their own:
# ['i', 'may', 'be', 'straight,', 'though', 'they', 'themselves', 'be', 'bevel;']
# i may
# i may be
# i may be straight,
# i may be straight, though
# i may be straight, though they
# i may be straight, though they themselves
# i may be straight, though they themselves be
# i may be straight, though they themselves be bevel;
# ['by', 'their', 'rank', 'thoughts', 'my', 'deeds', 'must', 'not', 'be', 'shown;']
# by their
# by their rank
# by their rank thoughts
# by their rank thoughts my
# by their rank thoughts my deeds
# by their rank thoughts my deeds must
# by their rank thoughts my deeds must not
# by their rank thoughts my deeds must not be
# by their rank thoughts my deeds must not be shown;
# ['unless', 'this', 'general', 'evil', 'they', 'maintain,']
# unless this
# unless this general
# unless this general evil
# unless this general evil they
# unless this general evil they maintain,
# ['all', 'men', 'are', 'bad,', 'and', 'in', 'their', 'badness', 'reign.']
# all men
# all men are
# all men are bad,
# all men are bad, and
# all men are bad, and in
# all men are bad, and in their
# all men are bad, and in their badness
# all men are bad, and in their badness reign.
# ['thy', 'gift,', 'thy', 'tables,', 'are', 'within', 'my', 'brain']
# thy gift,
# thy gift, thy
# thy gift, thy tables,
# thy gift, thy tables, are
# thy gift, thy tables, are within
# thy gift, thy tables, are within my
# thy gift, thy tables, are within my brain
# ['full', "character'd", 'with', 'lasting', 'memory,']
# full character'd
# full character'd with
# full character'd with lasting
# full character'd with lasting memory,
# ['which', 'shall', 'above', 'that', 'idle', 'rank', 'remain']
# which shall
# which shall above
# which shall above that
# which shall above that idle
# which shall above that idle rank
# which shall above that idle rank remain
# ['beyond', 'all', 'date,', 'even', 'to', 'eternity;']
# beyond all
# beyond all date,
# beyond all date, even
# beyond all date, even to
# beyond all date, even to eternity;
# ['or', 'at', 'the', 'least,', 'so', 'long', 'as', 'brain', 'and', 'heart']
# or at
# or at the
# or at the least,
# or at the least, so
# or at the least, so long
# or at the least, so long as
# or at the least, so long as brain
# or at the least, so long as brain and
# or at the least, so long as brain and heart
# ['have', 'faculty', 'by', 'nature', 'to', 'subsist;']
# have faculty
# have faculty by
# have faculty by nature
# have faculty by nature to
# have faculty by nature to subsist;
# ['till', 'each', 'to', 'razed', 'oblivion', 'yield', 'his', 'part']
# till each
# till each to
# till each to razed
# till each to razed oblivion
# till each to razed oblivion yield
# till each to razed oblivion yield his
# till each to razed oblivion yield his part
# ['of', 'thee,', 'thy', 'record', 'never', 'can', 'be', "miss'd."]
# of thee,
# of thee, thy
# of thee, thy record
# of thee, thy record never
# of thee, thy record never can
# of thee, thy record never can be
# of thee, thy record never can be miss'd.
# ['that', 'poor', 'retention', 'could', 'not', 'so', 'much', 'hold,']
# that poor
# that poor retention
# that poor retention could
# that poor retention could not
# that poor retention could not so
# that poor retention could not so much
# that poor retention could not so much hold,
# ['nor', 'need', 'i', 'tallies', 'thy', 'dear', 'love', 'to', 'score;']
# nor need
# nor need i
# nor need i tallies
# nor need i tallies thy
# nor need i tallies thy dear
# nor need i tallies thy dear love
# nor need i tallies thy dear love to
# nor need i tallies thy dear love to score;
# ['therefore', 'to', 'give', 'them', 'from', 'me', 'was', 'i', 'bold,']
# therefore to
# therefore to give
# therefore to give them
# therefore to give them from
# therefore to give them from me
# therefore to give them from me was
# therefore to give them from me was i
# therefore to give them from me was i bold,
# ['to', 'trust', 'those', 'tables', 'that', 'receive', 'thee', 'more:']
# to trust
# to trust those
# to trust those tables
# to trust those tables that
# to trust those tables that receive
# to trust those tables that receive thee
# to trust those tables that receive thee more:
# ['to', 'keep', 'an', 'adjunct', 'to', 'remember', 'thee']
# to keep
# to keep an
# to keep an adjunct
# to keep an adjunct to
# to keep an adjunct to remember
# to keep an adjunct to remember thee
# ['were', 'to', 'import', 'forgetfulness', 'in', 'me.']
# were to
# were to import
# were to import forgetfulness
# were to import forgetfulness in
# were to import forgetfulness in me.
# ['no,', 'time,', 'thou', 'shalt', 'not', 'boast', 'that', 'i', 'do', 'change:']
# no, time,
# no, time, thou
# no, time, thou shalt
# no, time, thou shalt not
# no, time, thou shalt not boast
# no, time, thou shalt not boast that
# no, time, thou shalt not boast that i
# no, time, thou shalt not boast that i do
# no, time, thou shalt not boast that i do change:
# ['thy', 'pyramids', 'built', 'up', 'with', 'newer', 'might']
# thy pyramids
# thy pyramids built
# thy pyramids built up
# thy pyramids built up with
# thy pyramids built up with newer
# thy pyramids built up with newer might
# ['to', 'me', 'are', 'nothing', 'novel,', 'nothing', 'strange;']
# to me
# to me are
# to me are nothing
# to me are nothing novel,
# to me are nothing novel, nothing
# to me are nothing novel, nothing strange;
# ['they', 'are', 'but', 'dressings', 'of', 'a', 'former', 'sight.']
# they are
# they are but
# they are but dressings
# they are but dressings of
# they are but dressings of a
# they are but dressings of a former
# they are but dressings of a former sight.
# ['our', 'dates', 'are', 'brief,', 'and', 'therefore', 'we', 'admire']
# our dates
# our dates are
# our dates are brief,
# our dates are brief, and
# our dates are brief, and therefore
# our dates are brief, and therefore we
# our dates are brief, and therefore we admire
# ['what', 'thou', 'dost', 'foist', 'upon', 'us', 'that', 'is', 'old,']
# what thou
# what thou dost
# what thou dost foist
# what thou dost foist upon
# what thou dost foist upon us
# what thou dost foist upon us that
# what thou dost foist upon us that is
# what thou dost foist upon us that is old,
# ['and', 'rather', 'make', 'them', 'born', 'to', 'our', 'desire']
# and rather
# and rather make
# and rather make them
# and rather make them born
# and rather make them born to
# and rather make them born to our
# and rather make them born to our desire
# ['than', 'think', 'that', 'we', 'before', 'have', 'heard', 'them', 'told.']
# than think
# than think that
# than think that we
# than think that we before
# than think that we before have
# than think that we before have heard
# than think that we before have heard them
# than think that we before have heard them told.
# ['thy', 'registers', 'and', 'thee', 'i', 'both', 'defy,']
# thy registers
# thy registers and
# thy registers and thee
# thy registers and thee i
# thy registers and thee i both
# thy registers and thee i both defy,
# ['not', 'wondering', 'at', 'the', 'present', 'nor', 'the', 'past,']
# not wondering
# not wondering at
# not wondering at the
# not wondering at the present
# not wondering at the present nor
# not wondering at the present nor the
# not wondering at the present nor the past,
# ['for', 'thy', 'records', 'and', 'what', 'we', 'see', 'doth', 'lie,']
# for thy
# for thy records
# for thy records and
# for thy records and what
# for thy records and what we
# for thy records and what we see
# for thy records and what we see doth
# for thy records and what we see doth lie,
# ['made', 'more', 'or', 'less', 'by', 'thy', 'continual', 'haste.']
# made more
# made more or
# made more or less
# made more or less by
# made more or less by thy
# made more or less by thy continual
# made more or less by thy continual haste.
# ['this', 'i', 'do', 'vow', 'and', 'this', 'shall', 'ever', 'be;']
# this i
# this i do
# this i do vow
# this i do vow and
# this i do vow and this
# this i do vow and this shall
# this i do vow and this shall ever
# this i do vow and this shall ever be;
# ['i', 'will', 'be', 'true,', 'despite', 'thy', 'scythe', 'and', 'thee.']
# i will
# i will be
# i will be true,
# i will be true, despite
# i will be true, despite thy
# i will be true, despite thy scythe
# i will be true, despite thy scythe and
# i will be true, despite thy scythe and thee.
# ['if', 'my', 'dear', 'love', 'were', 'but', 'the', 'child', 'of', 'state,']
# if my
# if my dear
# if my dear love
# if my dear love were
# if my dear love were but
# if my dear love were but the
# if my dear love were but the child
# if my dear love were but the child of
# if my dear love were but the child of state,
# ['it', 'might', 'for', "fortune's", 'bastard', 'be', "unfather'd'"]
# it might
# it might for
# it might for fortune's
# it might for fortune's bastard
# it might for fortune's bastard be
# it might for fortune's bastard be unfather'd'
# ['as', 'subject', 'to', "time's", 'love', 'or', 'to', "time's", 'hate,']
# as subject
# as subject to
# as subject to time's
# as subject to time's love
# as subject to time's love or
# as subject to time's love or to
# as subject to time's love or to time's
# as subject to time's love or to time's hate,
# ['weeds', 'among', 'weeds,', 'or', 'flowers', 'with', 'flowers', "gather'd."]
# weeds among
# weeds among weeds,
# weeds among weeds, or
# weeds among weeds, or flowers
# weeds among weeds, or flowers with
# weeds among weeds, or flowers with flowers
# weeds among weeds, or flowers with flowers gather'd.
# ['no,', 'it', 'was', 'builded', 'far', 'from', 'accident;']
# no, it
# no, it was
# no, it was builded
# no, it was builded far
# no, it was builded far from
# no, it was builded far from accident;
# ['it', 'suffers', 'not', 'in', 'smiling', 'pomp,', 'nor', 'falls']
# it suffers
# it suffers not
# it suffers not in
# it suffers not in smiling
# it suffers not in smiling pomp,
# it suffers not in smiling pomp, nor
# it suffers not in smiling pomp, nor falls
# ['under', 'the', 'blow', 'of', 'thralled', 'discontent,']
# under the
# under the blow
# under the blow of
# under the blow of thralled
# under the blow of thralled discontent,
# ['whereto', 'the', 'inviting', 'time', 'our', 'fashion', 'calls:']
# whereto the
# whereto the inviting
# whereto the inviting time
# whereto the inviting time our
# whereto the inviting time our fashion
# whereto the inviting time our fashion calls:
# ['it', 'fears', 'not', 'policy,', 'that', 'heretic,']
# it fears
# it fears not
# it fears not policy,
# it fears not policy, that
# it fears not policy, that heretic,
# ['which', 'works', 'on', 'leases', 'of', "short-number'd", 'hours,']
# which works
# which works on
# which works on leases
# which works on leases of
# which works on leases of short-number'd
# which works on leases of short-number'd hours,
# ['but', 'all', 'alone', 'stands', 'hugely', 'politic,']
# but all
# but all alone
# but all alone stands
# but all alone stands hugely
# but all alone stands hugely politic,
# ['that', 'it', 'nor', 'grows', 'with', 'heat', 'nor', 'drowns', 'with', 'showers.']
# that it
# that it nor
# that it nor grows
# that it nor grows with
# that it nor grows with heat
# that it nor grows with heat nor
# that it nor grows with heat nor drowns
# that it nor grows with heat nor drowns with
# that it nor grows with heat nor drowns with showers.
# ['to', 'this', 'i', 'witness', 'call', 'the', 'fools', 'of', 'time,']
# to this
# to this i
# to this i witness
# to this i witness call
# to this i witness call the
# to this i witness call the fools
# to this i witness call the fools of
# to this i witness call the fools of time,
# ...
# who taught thee how to
# who taught thee how to make
# who taught thee how to make me
# who taught thee how to make me love
# who taught thee how to make me love thee
# who taught thee how to make me love thee more
# ['the', 'more', 'i', 'hear', 'and', 'see', 'just', 'cause', 'of', 'hate?']
# the more
# the more i
# the more i hear
# the more i hear and
# the more i hear and see
# the more i hear and see just
# the more i hear and see just cause
# the more i hear and see just cause of
# the more i hear and see just cause of hate?
# ['o,', 'though', 'i', 'love', 'what', 'others', 'do', 'abhor,']
# o, though
# o, though i
# o, though i love
# o, though i love what
# o, though i love what others
# o, though i love what others do
# o, though i love what others do abhor,
# ['with', 'others', 'thou', 'shouldst', 'not', 'abhor', 'my', 'state:']
# with others
# with others thou
# with others thou shouldst
# with others thou shouldst not
# with others thou shouldst not abhor
# with others thou shouldst not abhor my
# with others thou shouldst not abhor my state:
# ['if', 'thy', 'unworthiness', 'raised', 'love', 'in', 'me,']
# if thy
# if thy unworthiness
# if thy unworthiness raised
# if thy unworthiness raised love
# if thy unworthiness raised love in
# if thy unworthiness raised love in me,
# ['more', 'worthy', 'i', 'to', 'be', 'beloved', 'of', 'thee.']
# more worthy
# more worthy i
# more worthy i to
# more worthy i to be
# more worthy i to be beloved
# more worthy i to be beloved of
# more worthy i to be beloved of thee.
# ['love', 'is', 'too', 'young', 'to', 'know', 'what', 'conscience', 'is;']
# love is
# love is too
# love is too young
# love is too young to
# love is too young to know
# love is too young to know what
# love is too young to know what conscience
# love is too young to know what conscience is;
# ['yet', 'who', 'knows', 'not', 'conscience', 'is', 'born', 'of', 'love?']
# yet who
# yet who knows
# yet who knows not
# yet who knows not conscience
# yet who knows not conscience is
# yet who knows not conscience is born
# yet who knows not conscience is born of
# yet who knows not conscience is born of love?
# ['then,', 'gentle', 'cheater,', 'urge', 'not', 'my', 'amiss,']
# then, gentle
# then, gentle cheater,
# then, gentle cheater, urge
# then, gentle cheater, urge not
# then, gentle cheater, urge not my
# then, gentle cheater, urge not my amiss,
# ['lest', 'guilty', 'of', 'my', 'faults', 'thy', 'sweet', 'self', 'prove:']
# lest guilty
# lest guilty of
# lest guilty of my
# lest guilty of my faults
# lest guilty of my faults thy
# lest guilty of my faults thy sweet
# lest guilty of my faults thy sweet self
# lest guilty of my faults thy sweet self prove:
# ['for,', 'thou', 'betraying', 'me,', 'i', 'do', 'betray']
# for, thou
# for, thou betraying
# for, thou betraying me,
# for, thou betraying me, i
# for, thou betraying me, i do
# for, thou betraying me, i do betray
# ['my', 'nobler', 'part', 'to', 'my', 'gross', "body's", 'treason;']
# my nobler
# my nobler part
# my nobler part to
# my nobler part to my
# my nobler part to my gross
# my nobler part to my gross body's
# my nobler part to my gross body's treason;
# ['my', 'soul', 'doth', 'tell', 'my', 'body', 'that', 'he', 'may']
# my soul
# my soul doth
# my soul doth tell
# my soul doth tell my
# my soul doth tell my body
# my soul doth tell my body that
# my soul doth tell my body that he
# my soul doth tell my body that he may
# ['triumph', 'in', 'love;', 'flesh', 'stays', 'no', 'father', 'reason;']
# triumph in
# triumph in love;
# triumph in love; flesh
# triumph in love; flesh stays
# triumph in love; flesh stays no
# triumph in love; flesh stays no father
# triumph in love; flesh stays no father reason;
# ['but,', 'rising', 'at', 'thy', 'name,', 'doth', 'point', 'out', 'thee']
# but, rising
# but, rising at
# but, rising at thy
# but, rising at thy name,
# but, rising at thy name, doth
# but, rising at thy name, doth point
# but, rising at thy name, doth point out
# but, rising at thy name, doth point out thee
# ['as', 'his', 'triumphant', 'prize.', 'proud', 'of', 'this', 'pride,']
# as his
# as his triumphant
# as his triumphant prize.
# as his triumphant prize. proud
# as his triumphant prize. proud of
# as his triumphant prize. proud of this
# as his triumphant prize. proud of this pride,
# ['he', 'is', 'contented', 'thy', 'poor', 'drudge', 'to', 'be,']
# he is
# he is contented
# he is contented thy
# he is contented thy poor
# he is contented thy poor drudge
# he is contented thy poor drudge to
# he is contented thy poor drudge to be,
# ['to', 'stand', 'in', 'thy', 'affairs,', 'fall', 'by', 'thy', 'side.']
# to stand
# to stand in
# to stand in thy
# to stand in thy affairs,
# to stand in thy affairs, fall
# to stand in thy affairs, fall by
# to stand in thy affairs, fall by thy
# to stand in thy affairs, fall by thy side.
# ['no', 'want', 'of', 'conscience', 'hold', 'it', 'that', 'i', 'call']
# no want
# no want of
# no want of conscience
# no want of conscience hold
# no want of conscience hold it
# no want of conscience hold it that
# no want of conscience hold it that i
# no want of conscience hold it that i call
# ['her', 'love', 'for', 'whose', 'dear', 'love', 'i', 'rise', 'and', 'fall.']
# her love
# her love for
# her love for whose
# her love for whose dear
# her love for whose dear love
# her love for whose dear love i
# her love for whose dear love i rise
# her love for whose dear love i rise and
# her love for whose dear love i rise and fall.
# ['in', 'loving', 'thee', 'thou', "know'st", 'i', 'am', 'forsworn,']
# in loving
# in loving thee
# in loving thee thou
# in loving thee thou know'st
# in loving thee thou know'st i
# in loving thee thou know'st i am
# in loving thee thou know'st i am forsworn,
# ['but', 'thou', 'art', 'twice', 'forsworn,', 'to', 'me', 'love', 'swearing,']
# but thou
# but thou art
# but thou art twice
# but thou art twice forsworn,
# but thou art twice forsworn, to
# but thou art twice forsworn, to me
# but thou art twice forsworn, to me love
# but thou art twice forsworn, to me love swearing,
# ['in', 'act', 'thy', 'bed-vow', 'broke', 'and', 'new', 'faith', 'torn,']
# in act
# in act thy
# in act thy bed-vow
# in act thy bed-vow broke
# in act thy bed-vow broke and
# in act thy bed-vow broke and new
# in act thy bed-vow broke and new faith
# in act thy bed-vow broke and new faith torn,
# ['in', 'vowing', 'new', 'hate', 'after', 'new', 'love', 'bearing.']
# in vowing
# in vowing new
# in vowing new hate
# in vowing new hate after
# in vowing new hate after new
# in vowing new hate after new love
# in vowing new hate after new love bearing.
# ['but', 'why', 'of', 'two', "oaths'", 'breach', 'do', 'i', 'accuse', 'thee,']
# but why
# but why of
# but why of two
# but why of two oaths'
# but why of two oaths' breach
# but why of two oaths' breach do
# but why of two oaths' breach do i
# but why of two oaths' breach do i accuse
# but why of two oaths' breach do i accuse thee,
# ['when', 'i', 'break', 'twenty?', 'i', 'am', 'perjured', 'most;']
# when i
# when i break
# when i break twenty?
# when i break twenty? i
# when i break twenty? i am
# when i break twenty? i am perjured
# when i break twenty? i am perjured most;
# ['for', 'all', 'my', 'vows', 'are', 'oaths', 'but', 'to', 'misuse', 'thee']
# for all
# for all my
# for all my vows
# for all my vows are
# for all my vows are oaths
# for all my vows are oaths but
# for all my vows are oaths but to
# for all my vows are oaths but to misuse
# for all my vows are oaths but to misuse thee
# ['and', 'all', 'my', 'honest', 'faith', 'in', 'thee', 'is', 'lost,']
# and all
# and all my
# and all my honest
# and all my honest faith
# and all my honest faith in
# and all my honest faith in thee
# and all my honest faith in thee is
# and all my honest faith in thee is lost,
# ['for', 'i', 'have', 'sworn', 'deep', 'oaths', 'of', 'thy', 'deep', 'kindness,']
# for i
# for i have
# for i have sworn
# for i have sworn deep
# for i have sworn deep oaths
# for i have sworn deep oaths of
# for i have sworn deep oaths of thy
# for i have sworn deep oaths of thy deep
# for i have sworn deep oaths of thy deep kindness,
# ['oaths', 'of', 'thy', 'love,', 'thy', 'truth,', 'thy', 'constancy,']
# oaths of
# oaths of thy
# oaths of thy love,
# oaths of thy love, thy
# oaths of thy love, thy truth,
# oaths of thy love, thy truth, thy
# oaths of thy love, thy truth, thy constancy,
# ['and,', 'to', 'enlighten', 'thee,', 'gave', 'eyes', 'to', 'blindness,']
# and, to
# and, to enlighten
# and, to enlighten thee,
# and, to enlighten thee, gave
# and, to enlighten thee, gave eyes
# and, to enlighten thee, gave eyes to
# and, to enlighten thee, gave eyes to blindness,
# ['or', 'made', 'them', 'swear', 'against', 'the', 'thing', 'they', 'see;']
# or made
# or made them
# or made them swear
# or made them swear against
# or made them swear against the
# or made them swear against the thing
# or made them swear against the thing they
# or made them swear against the thing they see;
# ['for', 'i', 'have', 'sworn', 'thee', 'fair;', 'more', 'perjured', 'eye,']
# for i
# for i have
# for i have sworn
# for i have sworn thee
# for i have sworn thee fair;
# for i have sworn thee fair; more
# for i have sworn thee fair; more perjured
# for i have sworn thee fair; more perjured eye,
# ['to', 'swear', 'against', 'the', 'truth', 'so', 'foul', 'a', 'lie!']
# to swear
# to swear against
# to swear against the
# to swear against the truth
# to swear against the truth so
# to swear against the truth so foul
# to swear against the truth so foul a
# to swear against the truth so foul a lie!
# ['cupid', 'laid', 'by', 'his', 'brand,', 'and', 'fell', 'asleep:']
# cupid laid
# cupid laid by
# cupid laid by his
# cupid laid by his brand,
# cupid laid by his brand, and
# cupid laid by his brand, and fell
# cupid laid by his brand, and fell asleep:
# ['a', 'maid', 'of', "dian's", 'this', 'advantage', 'found,']
# a maid
# a maid of
# a maid of dian's
# a maid of dian's this
# a maid of dian's this advantage
# a maid of dian's this advantage found,
# ['and', 'his', 'love-kindling', 'fire', 'did', 'quickly', 'steep']
# and his
# and his love-kindling
# and his love-kindling fire
# and his love-kindling fire did
# and his love-kindling fire did quickly
# and his love-kindling fire did quickly steep
# ['in', 'a', 'cold', 'valley-fountain', 'of', 'that', 'ground;']
# in a
# in a cold
# in a cold valley-fountain
# in a cold valley-fountain of
# in a cold valley-fountain of that
# in a cold valley-fountain of that ground;
# ['which', "borrow'd", 'from', 'this', 'holy', 'fire', 'of', 'love']
# which borrow'd
# which borrow'd from
# which borrow'd from this
# which borrow'd from this holy
# which borrow'd from this holy fire
# which borrow'd from this holy fire of
# which borrow'd from this holy fire of love
# ['a', 'dateless', 'lively', 'heat,', 'still', 'to', 'endure,']
# a dateless
# a dateless lively
# a dateless lively heat,
# a dateless lively heat, still
# a dateless lively heat, still to
# a dateless lively heat, still to endure,
# ['and', 'grew', 'a', 'seething', 'bath,', 'which', 'yet', 'men', 'prove']
# and grew
# and grew a
# and grew a seething
# and grew a seething bath,
# and grew a seething bath, which
# and grew a seething bath, which yet
# and grew a seething bath, which yet men
# and grew a seething bath, which yet men prove
# ['against', 'strange', 'maladies', 'a', 'sovereign', 'cure.']
# against strange
# against strange maladies
# against strange maladies a
# against strange maladies a sovereign
# against strange maladies a sovereign cure.
# ['but', 'at', 'my', "mistress'", 'eye', "love's", 'brand', 'new-fired,']
# but at
# but at my
# but at my mistress'
# but at my mistress' eye
# but at my mistress' eye love's
# but at my mistress' eye love's brand
# but at my mistress' eye love's brand new-fired,
# ['the', 'boy', 'for', 'trial', 'needs', 'would', 'touch', 'my', 'breast;']
# the boy
# the boy for
# the boy for trial
# the boy for trial needs
# the boy for trial needs would
# the boy for trial needs would touch
# the boy for trial needs would touch my
# the boy for trial needs would touch my breast;
# ['i,', 'sick', 'withal,', 'the', 'help', 'of', 'bath', 'desired,']
# i, sick
# i, sick withal,
# i, sick withal, the
# i, sick withal, the help
# i, sick withal, the help of
# i, sick withal, the help of bath
# i, sick withal, the help of bath desired,
# ['and', 'thither', 'hied,', 'a', 'sad', "distemper'd", 'guest,']
# and thither
# and thither hied,
# and thither hied, a
# and thither hied, a sad
# and thither hied, a sad distemper'd
# and thither hied, a sad distemper'd guest,
# ['but', 'found', 'no', 'cure:', 'the', 'bath', 'for', 'my', 'help', 'lies']
# but found
# but found no
# but found no cure:
# but found no cure: the
# but found no cure: the bath
# but found no cure: the bath for
# but found no cure: the bath for my
# but found no cure: the bath for my help
# but found no cure: the bath for my help lies
# ['where', 'cupid', 'got', 'new', 'fire--my', "mistress'", 'eyes.']
# where cupid
# where cupid got
# where cupid got new
# where cupid got new fire--my
# where cupid got new fire--my mistress'
# where cupid got new fire--my mistress' eyes.
# ['the', 'little', 'love-god', 'lying', 'once', 'asleep']
# the little
# the little love-god
# the little love-god lying
# the little love-god lying once
# the little love-god lying once asleep
# ['laid', 'by', 'his', 'side', 'his', 'heart-inflaming', 'brand,']
# laid by
# laid by his
# laid by his side
# laid by his side his
# laid by his side his heart-inflaming
# laid by his side his heart-inflaming brand,
# ['whilst', 'many', 'nymphs', 'that', "vow'd", 'chaste', 'life', 'to', 'keep']
# whilst many
# whilst many nymphs
# whilst many nymphs that
# whilst many nymphs that vow'd
# whilst many nymphs that vow'd chaste
# whilst many nymphs that vow'd chaste life
# whilst many nymphs that vow'd chaste life to
# whilst many nymphs that vow'd chaste life to keep
# ['came', 'tripping', 'by;', 'but', 'in', 'her', 'maiden', 'hand']
# came tripping
# came tripping by;
# came tripping by; but
# came tripping by; but in
# came tripping by; but in her
# came tripping by; but in her maiden
# came tripping by; but in her maiden hand
# ['the', 'fairest', 'votary', 'took', 'up', 'that', 'fire']
# the fairest
# the fairest votary
# the fairest votary took
# the fairest votary took up
# the fairest votary took up that
# the fairest votary took up that fire
# ['which', 'many', 'legions', 'of', 'true', 'hearts', 'had', "warm'd;"]
# which many
# which many legions
# which many legions of
# which many legions of true
# which many legions of true hearts
# which many legions of true hearts had
# which many legions of true hearts had warm'd;
# ['and', 'so', 'the', 'general', 'of', 'hot', 'desire']
# and so
# and so the
# and so the general
# and so the general of
# and so the general of hot
# and so the general of hot desire
# ['was', 'sleeping', 'by', 'a', 'virgin', 'hand', "disarm'd."]
# was sleeping
# was sleeping by
# was sleeping by a
# was sleeping by a virgin
# was sleeping by a virgin hand
# was sleeping by a virgin hand disarm'd.
# ['this', 'brand', 'she', 'quenched', 'in', 'a', 'cool', 'well', 'by,']
# this brand
# this brand she
# this brand she quenched
# this brand she quenched in
# this brand she quenched in a
# this brand she quenched in a cool
# this brand she quenched in a cool well
# this brand she quenched in a cool well by,
# ['which', 'from', "love's", 'fire', 'took', 'heat', 'perpetual,']
# which from
# which from love's
# which from love's fire
# which from love's fire took
# which from love's fire took heat
# which from love's fire took heat perpetual,
# ['growing', 'a', 'bath', 'and', 'healthful', 'remedy']
# growing a
# growing a bath
# growing a bath and
# growing a bath and healthful
# growing a bath and healthful remedy
# ['for', 'men', 'diseased;', 'but', 'i,', 'my', "mistress'", 'thrall,']
# for men
# for men diseased;
# for men diseased; but
# for men diseased; but i,
# for men diseased; but i, my
# for men diseased; but i, my mistress'
# for men diseased; but i, my mistress' thrall,
# ['came', 'there', 'for', 'cure,', 'and', 'this', 'by', 'that', 'i', 'prove,']
# came there
# came there for
# came there for cure,
# came there for cure, and
# came there for cure, and this
# came there for cure, and this by
# came there for cure, and this by that
# came there for cure, and this by that i
# came there for cure, and this by that i prove,
# ["love's", 'fire', 'heats', 'water,', 'water', 'cools', 'not', 'love.']
# love's fire
# love's fire heats
# love's fire heats water,
# love's fire heats water, water
# love's fire heats water, water cools
# love's fire heats water, water cools not
# love's fire heats water, water cools not love.
# []
# n_grams of input_sequences have length: 15355
# maximum length of sequences is: 11

# %% [markdown]
# **Expected Output:**
#
# ```
# n_grams of input_sequences have length: 15462
# maximum length of sequences is: 11
# ```

# %% [markdown]
# ## Add padding to the sequences
#
# Now code the `pad_seqs` function which will pad any given sequences to the desired maximum length. Notice that this function receives a list of sequences and should return a numpy array with the padded sequences:

# %%
# GRADED FUNCTION: pad_seqs
def pad_seqs(input_sequences, maxlen):
    """
    Pads tokenized sequences to the same length
    
    Args:
        input_sequences (list of int): tokenized sequences to pad
        maxlen (int): maximum length of the token sequences
    
    Returns:
        padded_sequences (array of int): tokenized sequences padded to the same length
    """
    ### START CODE HERE
    padded_sequences = pad_sequences(input_sequences, maxlen=maxlen, padding='pre')
    
    return padded_sequences
    ### END CODE HERE

# %%
# Test your function with the n_grams_seq of the first example
first_padded_seq = pad_seqs(first_example_sequence, len(first_example_sequence))
first_padded_seq
# Out:
# array([[  0,   0,   0,  34, 417],
#        [  0,   0,  34, 417, 877],
#        [  0,  34, 417, 877, 166],
#        [ 34, 417, 877, 166, 213],
#        [417, 877, 166, 213, 517]], dtype=int32)

# %% [markdown]
# **Expected Output:**
#
# ```
# array([[  0,   0,   0,  34, 417],
#        [  0,   0,  34, 417, 877],
#        [  0,  34, 417, 877, 166],
#        [ 34, 417, 877, 166, 213],
#        [417, 877, 166, 213, 517]], dtype=int32)
# ```

# %%
# Test your function with the n_grams_seq of the next 3 examples
next_3_padded_seq = pad_seqs(next_3_examples_sequence, max([len(s) for s in next_3_examples_sequence]))
next_3_padded_seq
# Out:
# array([[  0,   0,   0,   0,   0,   0,   8, 878],
#        [  0,   0,   0,   0,   0,   8, 878, 134],
#        [  0,   0,   0,   0,   8, 878, 134, 351],
#        [  0,   0,   0,   8, 878, 134, 351, 102],
#        [  0,   0,   8, 878, 134, 351, 102, 156],
#        [  0,   8, 878, 134, 351, 102, 156, 199],
#        [  0,   0,   0,   0,   0,   0,  16,  22],
#        [  0,   0,   0,   0,   0,  16,  22,   2],
#        [  0,   0,   0,   0,  16,  22,   2, 879],
#        [  0,   0,   0,  16,  22,   2, 879,  61],
#        [  0,   0,  16,  22,   2, 879,  61,  30],
#        [  0,  16,  22,   2, 879,  61,  30,  48],
#        [ 16,  22,   2, 879,  61,  30,  48, 634],
#        [  0,   0,   0,   0,   0,   0,  25, 311],
#        [  0,   0,   0,   0,   0,  25, 311, 635],
#        [  0,   0,   0,   0,  25, 311, 635, 102],
#        [  0,   0,   0,  25, 311, 635, 102, 200],
#        [  0,   0,  25, 311, 635, 102, 200,  25],
#        [  0,  25, 311, 635, 102, 200,  25, 278]], dtype=int32)

# %% [markdown]
# **Expected Output:**
#
# ```
# array([[  0,   0,   0,   0,   0,   0,   8, 878],
#        [  0,   0,   0,   0,   0,   8, 878, 134],
#        [  0,   0,   0,   0,   8, 878, 134, 351],
#        [  0,   0,   0,   8, 878, 134, 351, 102],
#        [  0,   0,   8, 878, 134, 351, 102, 156],
#        [  0,   8, 878, 134, 351, 102, 156, 199],
#        [  0,   0,   0,   0,   0,   0,  16,  22],
#        [  0,   0,   0,   0,   0,  16,  22,   2],
#        [  0,   0,   0,   0,  16,  22,   2, 879],
#        [  0,   0,   0,  16,  22,   2, 879,  61],
#        [  0,   0,  16,  22,   2, 879,  61,  30],
#        [  0,  16,  22,   2, 879,  61,  30,  48],
#        [ 16,  22,   2, 879,  61,  30,  48, 634],
#        [  0,   0,   0,   0,   0,   0,  25, 311],
#        [  0,   0,   0,   0,   0,  25, 311, 635],
#        [  0,   0,   0,   0,  25, 311, 635, 102],
#        [  0,   0,   0,  25, 311, 635, 102, 200],
#        [  0,   0,  25, 311, 635, 102, 200,  25],
#        [  0,  25, 311, 635, 102, 200,  25, 278]], dtype=int32)
# ```

# %%
# Pad the whole corpus
input_sequences = pad_seqs(input_sequences, max_sequence_len)

print(f"padded corpus has shape: {input_sequences.shape}")
# Out:
# padded corpus has shape: (15355, 11)

# %% [markdown]
# **Expected Output:**
#
# ```
# padded corpus has shape: (15462, 11)
# ```

# %% [markdown]
# ## Split the data into features and labels
#
# Before feeding the data into the neural network you should split it into features and labels. In this case the features will be the padded n_gram sequences with the last word removed from them and the labels will be the removed word.
#
# Complete the `features_and_labels` function below. This function expects the padded n_gram sequences as input and should return a tuple containing the features and the one hot encoded labels.
#
# Notice that the function also receives the total of words in the corpus, this parameter will be very important when one hot enconding the labels since every word in the corpus will be a label at least once. If you need a refresh of how the `to_categorical` function works take a look at the [docs](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical)

# %%
# GRADED FUNCTION: features_and_labels
def features_and_labels(input_sequences, total_words):
    """
    Generates features and labels from n-grams
    
    Args:
        input_sequences (list of int): sequences to split features and labels from
        total_words (int): vocabulary size
    
    Returns:
        features, one_hot_labels (array of int, array of int): arrays of features and one-hot encoded labels
    """
    ### START CODE HERE
    features = input_sequences[:,:-1]
    labels = input_sequences[:,-1]
    one_hot_labels = to_categorical(labels, num_classes=total_words)
    ### END CODE HERE

    return features, one_hot_labels

# %%
# Test your function with the padded n_grams_seq of the first example
first_features, first_labels = features_and_labels(first_padded_seq, total_words)

print(f"labels have shape: {first_labels.shape}")
print("\nfeatures look like this:\n")
first_features
# Out:
# labels have shape: (5, 3211)
#
# features look like this:
# array([[  0,   0,   0,  34],
#        [  0,   0,  34, 417],
#        [  0,  34, 417, 877],
#        [ 34, 417, 877, 166],
#        [417, 877, 166, 213]], dtype=int32)

# %% [markdown]
# **Expected Output:**
#
# ```
# labels have shape: (5, 3211)
#
# features look like this:
#
# array([[  0,   0,   0,  34],
#        [  0,   0,  34, 417],
#        [  0,  34, 417, 877],
#        [ 34, 417, 877, 166],
#        [417, 877, 166, 213]], dtype=int32)
# ```

# %%
# Split the whole corpus
features, labels = features_and_labels(input_sequences, total_words)

print(f"features have shape: {features.shape}")
print(f"labels have shape: {labels.shape}")
# Out:
# features have shape: (15355, 10)
# labels have shape: (15355, 3211)

# %% [markdown]
# **Expected Output:**
#
# ```
# features have shape: (15462, 10)
# labels have shape: (15462, 3211)
# ```

# %% [markdown]
# ## Create the model
#
# Now you should define a model architecture capable of achieving an accuracy of at least 80%.
#
# Some hints to help you in this task:
#
# - An appropriate `output_dim` for the first layer (Embedding) is 100, this is already provided for you.
# - A Bidirectional LSTM is helpful for this particular problem.
# - The last layer should have the same number of units as the total number of words in the corpus and a softmax activation function.
# - This problem can be solved with only two layers (excluding the Embedding) so try out small architectures first.

# %%
# GRADED FUNCTION: create_model
def create_model(total_words, max_sequence_len):
    """
    Creates a text generator model
    
    Args:
        total_words (int): size of the vocabulary for the Embedding layer input
        max_sequence_len (int): length of the input sequences
    
    Returns:
        model (tf.keras Model): the text generator model
    """
    model = Sequential()
    ### START CODE HERE
    model.add(Embedding(total_words, 100, input_length=max_sequence_len - 1))
    #model.add(Bidirectional(GRU(50, return_sequences=True)))
    #model.add(Bidirectional(GRU(50, return_sequences=True)))
    #model.add(Bidirectional(GRU(50)))
    #model.add(Bidirectional(LSTM(80, return_sequences=True)))
    model.add(Bidirectional(LSTM(150)))
    #model.add(Dense(total_words, activation='relu'))
    #model.add(LSTM(100))
    model.add(Dense(total_words, activation='softmax'))


    # Compile the model
    model.compile(loss='categorical_crossentropy', 
      optimizer=Adam(learning_rate=0.005), 
      metrics=['accuracy'])
    
    ### END CODE HERE

    return model

# %%
# Get the untrained model
model = create_model(total_words, max_sequence_len)

# Train the model
history = model.fit(features, labels, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 480/480 [==============================] - 7s 8ms/step - loss: 6.7949 - accuracy: 0.0298
# Epoch 2/20
# 480/480 [==============================] - 4s 8ms/step - loss: 6.1595 - accuracy: 0.0529
# Epoch 3/20
# 480/480 [==============================] - 4s 8ms/step - loss: 5.5535 - accuracy: 0.0757
# Epoch 4/20
# 480/480 [==============================] - 4s 7ms/step - loss: 4.7317 - accuracy: 0.1263
# Epoch 5/20
# 480/480 [==============================] - 4s 8ms/step - loss: 3.7111 - accuracy: 0.2463
# Epoch 6/20
# 480/480 [==============================] - 4s 8ms/step - loss: 2.7302 - accuracy: 0.4114
# Epoch 7/20
# 480/480 [==============================] - 4s 8ms/step - loss: 1.9778 - accuracy: 0.5633
# Epoch 8/20
# 480/480 [==============================] - 4s 8ms/step - loss: 1.4578 - accuracy: 0.6827
# Epoch 9/20
# 480/480 [==============================] - 4s 8ms/step - loss: 1.1310 - accuracy: 0.7523
# Epoch 10/20
# 480/480 [==============================] - 4s 7ms/step - loss: 0.9249 - accuracy: 0.8006
# Epoch 11/20
# 480/480 [==============================] - 4s 8ms/step - loss: 0.8040 - accuracy: 0.8272
# Epoch 12/20
# 480/480 [==============================] - 4s 8ms/step - loss: 0.7358 - accuracy: 0.8376
# Epoch 13/20
# 480/480 [==============================] - 4s 8ms/step - loss: 0.7196 - accuracy: 0.8387
# Epoch 14/20
# 480/480 [==============================] - 4s 9ms/step - loss: 0.7687 - accuracy: 0.8240
# Epoch 15/20
# 480/480 [==============================] - 4s 7ms/step - loss: 0.9697 - accuracy: 0.7611
# Epoch 16/20
# 480/480 [==============================] - 4s 7ms/step - loss: 0.9222 - accuracy: 0.7734
# Epoch 17/20
# 480/480 [==============================] - 4s 7ms/step - loss: 0.7334 - accuracy: 0.8236
# Epoch 18/20
# 480/480 [==============================] - 4s 7ms/step - loss: 0.6433 - accuracy: 0.8449
# Epoch 19/20
# 480/480 [==============================] - 4s 8ms/step - loss: 0.6160 - accuracy: 0.8482
# Epoch 20/20
# 480/480 [==============================] - 4s 8ms/step - loss: 0.6041 - accuracy: 0.8485

# %% [markdown]
# **To pass this assignment, your model should achieve a training accuracy of at least 80%**. If your model didn't achieve this threshold, try training again with a different model architecture, consider increasing the number of unit in your `LSTM` layer.

# %%
# Take a look at the training curves of your model

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %% [markdown]
# Before closing the assignment, be sure to also download the `history.pkl` file which contains the information of the training history of your model and will be used to compute your grade. You can download this file by running the cell below:

# %%
def download_history():
  import pickle
  from google.colab import files

  with open('history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

  files.download('history.pkl')

download_history()

# %% [markdown]
# ## See your model in action
#
# After all your work it is finally time to see your model generating text.
#
# Run the cell below to generate the next 100 words of a seed text.
#
# After submitting your assignment you are encouraged to try out training for different amounts of epochs and seeing how this affects the coherency of the generated text. Also try changing the seed text to see what you get!

# %%
seed_text = "Help me Obi Wan Kenobi, you're my only hope"
next_words = 100
  
for _ in range(next_words):
	# Convert the text into sequences
	token_list = tokenizer.texts_to_sequences([seed_text])[0]
	# Pad the sequences
	token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
	# Get the probabilities of predicting a word
	predicted = model.predict(token_list, verbose=0)
	# Choose the next word based on the maximum probability
	predicted = np.argmax(predicted, axis=-1).item()
	# Get the actual word from the word index
	output_word = tokenizer.index_word[predicted]
	# Append to the current text
	seed_text += " " + output_word

print(seed_text)
# Out:
# Help me Obi Wan Kenobi, you're my only hope and most of care thee thee me old in thee thee thee me when waste muse thee this mine own waste so ' the treasure now mind now see ' blot me might ' have ' thee thee away i view thee again old blunt old have sourly i thee in smiling love all ' write but ' mine eye ' ' the wide which will away strange still alone ' ' thee thee eyes old offences of me a brow brow thee me me this thee thee thee thee thee thee when thee 'will' in heaven's sweetest bud mind

# %% [markdown]
# You will also need to submit this notebook for grading. To download it, click on the File tab in the upper left corner of the screen then click on Download -> Download .ipynb. You can name it anything you want as long as it is a valid .ipynb (jupyter notebook) file.
#
# **Congratulations on finishing this week's assignment!**
#
# You have successfully implemented a neural network capable of predicting the next word in a sequence of text!
#
# **We hope to see you in the next course of the specialization! Keep it up!**
